# %%
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials
import sqlite3
import datetime

# %%
ticker_source = pd.read_html('https://topforeignstocks.com/listed-companies-lists/the-complete-list-of-listed-companies-in-singapore/')[0]
print(ticker_source)
# Out:
#      S.No.      Trading Name    Code                            Sector
# 0        1           3Cnergy  502.SI                       Real Estate
# 1        2      5E Resources  NLC.SI  Industrial & Commercial Services
# 2        3          8Telecom  AZG.SI              Technology Equipment
# 3        4                9R  1Y1.SI                  Industrial Goods
# 4        5               ABR  533.SI                  Food & Beverages
# ..     ...               ...     ...                               ...
# 649    650  Zheneng Jinjiang  BWM.SI                  Renewable Energy
# 650    651   Zhongmin Baihui  5SR.SI                         Retailers
# 651    652    Zhongxin Fruit  5EG.SI                  Food & Beverages
# 652    653        ZICO Hldgs  40W.SI     Banking & Investment Services
# 653    654             Zixin  42W.SI                  Food & Beverages
#
# [654 rows x 4 columns]

# %%
example = yf.Ticker(ticker_source['Code'][0]).info
print(example)
print(example['quoteType'])
print(example['marketCap'])
print(example['averageVolume'])
first_trade_date = datetime.datetime.fromtimestamp(example['firstTradeDateEpochUtc']).strftime('%Y-%m-%d')
print(first_trade_date)
# Out:
# {'address1': '82 Ubi Avenue 4', 'address2': 'No. 05-04, Edward Boustead Centre', 'city': 'Singapore', 'zip': '408832', 'country': 'Singapore', 'phone': '65 6970 8117', 'website': 'https://www.3cnergy.com.sg', 'industry': 'Real Estate—Diversified', 'industryDisp': 'Real Estate—Diversified', 'sector': 'Real Estate', 'sectorDisp': 'Real Estate', 'longBusinessSummary': '3Cnergy Limited, an investment holding company, provides real estate and property development consultancy services in Singapore and Malaysia. It offers architectural design, project financial feasibility assessment, engineering expertise, and construction management services; and real estate valuation and appraisal services for housing and development board flats, private residential, commercial, and industrial properties for government agencies, financial institutions, corporations, and private individuals. The company was formerly known as HSR Global Limited and changed its name to 3Cnergy Limited in November 2013. 3Cnergy Limited was incorporated in 1973 and is based in Singapore.', 'companyOfficers': [{'maxAge': 1, 'name': 'Mr. Soon Hoe  Leow', 'title': 'Acting Group CEO & Group Financial Controller', 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Chang Lai Fong LLB (Hons)., MBA', 'title': 'Group Head of Legal and Compliance', 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Kok Siong  Yeo', 'title': 'Head of Marketing & Training', 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Hui Yee  Cheok', 'title': 'Sec.', 'exercisedValue': 0, 'unexercisedValue': 0}], 'maxAge': 86400, 'priceHint': 4, 'previousClose': 0.002, 'open': 0.002, 'dayLow': 0.002, 'dayHigh': 0.003, 'regularMarketPreviousClose': 0.002, 'regularMarketOpen': 0.002, 'regularMarketDayLow': 0.002, 'regularMarketDayHigh': 0.003, 'exDividendDate': 1652918400, 'volume': 33000, 'regularMarketVolume': 33000, 'averageVolume': 2103974, 'averageVolume10days': 215770, 'averageDailyVolume10Day': 215770, 'bid': 0.002, 'ask': 0.003, 'bidSize': 0, 'askSize': 0, 'marketCap': 9201150, 'fiftyTwoWeekLow': 0.001, 'fiftyTwoWeekHigh': 0.008, 'fiftyDayAverage': 0.00234, 'twoHundredDayAverage': 0.00239, 'trailingAnnualDividendRate': 0.0, 'trailingAnnualDividendYield': 0.0, 'currency': 'SGD', 'enterpriseValue': 6134108, 'profitMargins': 0.0, 'sharesOutstanding': 3067049984, 'heldPercentInsiders': 0.82264, 'heldPercentInstitutions': 0.0, 'impliedSharesOutstanding': 0, 'bookValue': 0.0, 'lastFiscalYearEnd': 1672444800, 'nextFiscalYearEnd': 1703980800, 'mostRecentQuarter': 1688083200, 'trailingEps': -0.0, '52WeekChange': -0.6666666, 'SandP52WeekChange': 0.055998206, 'lastDividendValue': 0.01164, 'lastDividendDate': 1652918400, 'exchange': 'SES', 'quoteType': 'EQUITY', 'symbol': '502.SI', 'underlyingSymbol': '502.SI', 'shortName': '$ 3Cnergy', 'longName': '3Cnergy Limited', 'firstTradeDateEpochUtc': 946861200, 'timeZoneFullName': 'Asia/Singapore', 'timeZoneShortName': 'SGT', 'uuid': 'c3abb28e-c7af-3ef0-8b87-7b27247d8e6e', 'messageBoardId': 'finmb_79611391', 'gmtOffSetMilliseconds': 28800000, 'currentPrice': 0.003, 'recommendationKey': 'none', 'revenuePerShare': 0.0, 'grossProfits': 499000, 'grossMargins': 0.0, 'ebitdaMargins': 0.0, 'operatingMargins': 0.0, 'financialCurrency': 'SGD', 'trailingPegRatio': None}
# EQUITY
# 9201150
# 2103974
# 2000-01-03

# %% [markdown]
# ## Filter out penny stocks
# 1. Stocks with a market cap above 10 million
# 2. Stocks with above 500k volume

# %%
from urllib.error import HTTPError

counter = 0
delisted = []
non_equity = []
insufficient_data = []
insufficient_market_cap = []

for idx, ticker in enumerate(ticker_source['Code']):
    
    try:
        data = yf.Ticker(ticker)
        quote_type = data.info['quoteType']
    except Exception as e:
        print(f"{ticker} is delisted")
        delisted.append(idx)
        continue
    
    if quote_type != 'EQUITY':
        print(f"{ticker} is not an equity. Data not retrieved.")
        non_equity.append(idx)
        continue
    
    if 'marketCap' not in data.info or 'averageVolume' not in data.info: 
        print(idx, ticker)
        print(f"{ticker} has insufficient data. Data not retrieved.")
        insufficient_data.append(idx)
        continue
    
    market_cap = data.info['marketCap']
    avg_volume = data.info['averageVolume']
    first_trade_date = datetime.datetime.fromtimestamp(example['firstTradeDateEpochUtc']).strftime('%Y-%m-%d')
    if market_cap < 10e6 or avg_volume < 500e3 or first_trade_date > '2010-01-01':
        print(f"{ticker} has insufficient market cap or average volume. Data not retrieved.")
        insufficient_market_cap.append(idx)       
    else:
        counter += 1
        
print(f"{counter} tickers have sufficient market cap and average volume.")
# Out:
# 502.SI has insufficient market cap or average volume. Data not retrieved.
# NLC.SI has insufficient market cap or average volume. Data not retrieved.
# AZG.SI is not an equity. Data not retrieved.
# 1Y1.SI has insufficient market cap or average volume. Data not retrieved.
# 533.SI has insufficient market cap or average volume. Data not retrieved.
# L5I.SI has insufficient market cap or average volume. Data not retrieved.
# 541.SI has insufficient market cap or average volume. Data not retrieved.
# 570.SI has insufficient market cap or average volume. Data not retrieved.
# QZG.SI has insufficient market cap or average volume. Data not retrieved.
# AYV.SI has insufficient market cap or average volume. Data not retrieved.
# 43F.SI has insufficient market cap or average volume. Data not retrieved.
# BLZ.SI has insufficient market cap or average volume. Data not retrieved.
# 43Q.SI has insufficient market cap or average volume. Data not retrieved.
# XVG.SI has insufficient market cap or average volume. Data not retrieved.
# 19 XWA.SI
# XWA.SI has insufficient data. Data not retrieved.
# L38.SI has insufficient market cap or average volume. Data not retrieved.
# 1A4.SI has insufficient market cap or average volume. Data not retrieved.
# BVP.SI has insufficient market cap or average volume. Data not retrieved.
# 40F.SI has insufficient market cap or average volume. Data not retrieved.
# MIJ.SI has insufficient market cap or average volume. Data not retrieved.
# VVL.SI has insufficient market cap or average volume. Data not retrieved.
# ZXY.SI has insufficient market cap or average volume. Data not retrieved.
# A34.SI has insufficient market cap or average volume. Data not retrieved.
# S9B.SI has insufficient market cap or average volume. Data not retrieved.
# 49B.SI has insufficient market cap or average volume. Data not retrieved.
# AOF.SI has insufficient market cap or average volume. Data not retrieved.
# HKB.SI has insufficient market cap or average volume. Data not retrieved.
# BTX.SI has insufficient market cap or average volume. Data not retrieved.
# A52.SI has insufficient market cap or average volume. Data not retrieved.
# 5AL.SI has insufficient market cap or average volume. Data not retrieved.
# 1D4.SI has insufficient market cap or average volume. Data not retrieved.
# 5AU.SI has insufficient market cap or average volume. Data not retrieved.
# 5RA.SI has insufficient market cap or average volume. Data not retrieved.
# CLN.SI has insufficient market cap or average volume. Data not retrieved.
# XZL.SI has insufficient market cap or average volume. Data not retrieved.
# YYB.SI has insufficient market cap or average volume. Data not retrieved.
# AWG.SI has insufficient market cap or average volume. Data not retrieved.
# A55.SI has insufficient market cap or average volume. Data not retrieved.
# 5RE.SI has insufficient market cap or average volume. Data not retrieved.
# 505.SI has insufficient market cap or average volume. Data not retrieved.
# 585.SI has insufficient market cap or average volume. Data not retrieved.
# S7OU.SI has insufficient market cap or average volume. Data not retrieved.
# 5WV.SI has insufficient market cap or average volume. Data not retrieved.
# 5CR.SI has insufficient market cap or average volume. Data not retrieved.
# BQC.SI has insufficient market cap or average volume. Data not retrieved.
# BTJ.SI has insufficient market cap or average volume. Data not retrieved.
# A30.SI has insufficient market cap or average volume. Data not retrieved.
# 5UF.SI has insufficient market cap or average volume. Data not retrieved.
# 42S.SI has insufficient market cap or average volume. Data not retrieved.
# 575.SI has insufficient market cap or average volume. Data not retrieved.
# 5UL.SI has insufficient market cap or average volume. Data not retrieved.
# 1AZ.SI has insufficient market cap or average volume. Data not retrieved.
# 5GJ.SI has insufficient market cap or average volume. Data not retrieved.
# U09.SI has insufficient market cap or average volume. Data not retrieved.
# 1R6.SI has insufficient market cap or average volume. Data not retrieved.
# A05.SI has insufficient market cap or average volume. Data not retrieved.
# 42U.SI has insufficient market cap or average volume. Data not retrieved.
# IXOR.SI is not an equity. Data not retrieved.
# QPQR.SI is not an equity. Data not retrieved.
# BBW.SI has insufficient market cap or average volume. Data not retrieved.
# CJN.SI has insufficient market cap or average volume. Data not retrieved.
# BTP.SI has insufficient market cap or average volume. Data not retrieved.
# B26.SI has insufficient market cap or average volume. Data not retrieved.
# B58.SI has insufficient market cap or average volume. Data not retrieved.
# KJ5.SI has insufficient market cap or average volume. Data not retrieved.
# BQN.SI has insufficient market cap or average volume. Data not retrieved.
# BMGU.SI has insufficient market cap or average volume. Data not retrieved.
# 8YY.SI has insufficient market cap or average volume. Data not retrieved.
# 41H.SI has insufficient market cap or average volume. Data not retrieved.
# 5VI.SI has insufficient market cap or average volume. Data not retrieved.
# B28.SI has insufficient market cap or average volume. Data not retrieved.
# F9D.SI has insufficient market cap or average volume. Data not retrieved.
# AVM.SI has insufficient market cap or average volume. Data not retrieved.
# BEC.SI has insufficient market cap or average volume. Data not retrieved.
# B69.SI has insufficient market cap or average volume. Data not retrieved.
# AWC.SI has insufficient market cap or average volume. Data not retrieved.
# B61.SI has insufficient market cap or average volume. Data not retrieved.
# BTE.SI has insufficient market cap or average volume. Data not retrieved.
# BAC.SI is not an equity. Data not retrieved.
# 594.SI has insufficient market cap or average volume. Data not retrieved.
# 1D5.SI has insufficient market cap or average volume. Data not retrieved.
# JWTU.SI is not an equity. Data not retrieved.
# AWV.SI has insufficient market cap or average volume. Data not retrieved.
# C04.SI has insufficient market cap or average volume. Data not retrieved.
# BXE.SI has insufficient market cap or average volume. Data not retrieved.
# 5EB.SI has insufficient market cap or average volume. Data not retrieved.
# C13.SI has insufficient market cap or average volume. Data not retrieved.
# 573.SI has insufficient market cap or average volume. Data not retrieved.
# 5QT.SI has insufficient market cap or average volume. Data not retrieved.
# 5NV.SI has insufficient market cap or average volume. Data not retrieved.
# C05.SI has insufficient market cap or average volume. Data not retrieved.
# G92.SI has insufficient market cap or average volume. Data not retrieved.
# 115 5OU.SI
# 5OU.SI has insufficient data. Data not retrieved.
# RS1.SI has insufficient market cap or average volume. Data not retrieved.
# U9E.SI has insufficient market cap or average volume. Data not retrieved.
# B0Z.SI is not an equity. Data not retrieved.
# BEH.SI has insufficient market cap or average volume. Data not retrieved.
# BHD.SI has insufficient market cap or average volume. Data not retrieved.
# BCD.SI has insufficient market cap or average volume. Data not retrieved.
# P74.SI has insufficient market cap or average volume. Data not retrieved.
# GU5.SI has insufficient market cap or average volume. Data not retrieved.
# QES.SI has insufficient market cap or average volume. Data not retrieved.
# 42E.SI has insufficient market cap or average volume. Data not retrieved.
# C33.SI has insufficient market cap or average volume. Data not retrieved.
# P9D.SI has insufficient market cap or average volume. Data not retrieved.
# 5TP.SI has insufficient market cap or average volume. Data not retrieved.
# STC.SI has insufficient market cap or average volume. Data not retrieved.
# N0Z.SI has insufficient market cap or average volume. Data not retrieved.
# P8A.SI has insufficient market cap or average volume. Data not retrieved.
# C41.SI has insufficient market cap or average volume. Data not retrieved.
# B9S.SI has insufficient market cap or average volume. Data not retrieved.
# CIN.SI has insufficient market cap or average volume. Data not retrieved.
# C76.SI has insufficient market cap or average volume. Data not retrieved.
# TCU.SI has insufficient market cap or average volume. Data not retrieved.
# CWBU.SI has insufficient market cap or average volume. Data not retrieved.
# CWCU.SI has insufficient market cap or average volume. Data not retrieved.
# DHLU.SI has insufficient market cap or average volume. Data not retrieved.
# BLR.SI has insufficient market cap or average volume. Data not retrieved.
# CEDU.SI has insufficient market cap or average volume. Data not retrieved.
# BTF.SI has insufficient market cap or average volume. Data not retrieved.
# D03.SI has insufficient market cap or average volume. Data not retrieved.
# D01.SI has insufficient market cap or average volume. Data not retrieved.
# BAI.SI has insufficient market cap or average volume. Data not retrieved.
# GRQ.SI has insufficient market cap or average volume. Data not retrieved.
# MT1.SI is not an equity. Data not retrieved.
# 5SO.SI has insufficient market cap or average volume. Data not retrieved.
# LIW.SI has insufficient market cap or average volume. Data not retrieved.
# BWCU.SI has insufficient market cap or average volume. Data not retrieved.
# EHG.SI has insufficient market cap or average volume. Data not retrieved.
# 5CT.SI has insufficient market cap or average volume. Data not retrieved.
# 5HG.SI has insufficient market cap or average volume. Data not retrieved.
# 42Z.SI has insufficient market cap or average volume. Data not retrieved.
# MXNU.SI has insufficient market cap or average volume. Data not retrieved.
# BIX.SI has insufficient market cap or average volume. Data not retrieved.
# S44.SI has insufficient market cap or average volume. Data not retrieved.
# 5RC.SI has insufficient market cap or average volume. Data not retrieved.
# 1C0.SI has insufficient market cap or average volume. Data not retrieved.
# 5G1.SI has insufficient market cap or average volume. Data not retrieved.
# ZKX.SI has insufficient market cap or average volume. Data not retrieved.
# 5DN.SI has insufficient market cap or average volume. Data not retrieved.
# F99.SI has insufficient market cap or average volume. Data not retrieved.
# 5FL.SI has insufficient market cap or average volume. Data not retrieved.
# 5TJ.SI has insufficient market cap or average volume. Data not retrieved.
# O10.SI has insufficient market cap or average volume. Data not retrieved.
# BDU.SI has insufficient market cap or average volume. Data not retrieved.
# 5F4.SI has insufficient market cap or average volume. Data not retrieved.
# ADN.SI has insufficient market cap or average volume. Data not retrieved.
# 8A1.SI has insufficient market cap or average volume. Data not retrieved.
# OAJ.SI has insufficient market cap or average volume. Data not retrieved.
# ACV.SI has insufficient market cap or average volume. Data not retrieved.
# TQ5.SI has insufficient market cap or average volume. Data not retrieved.
# D8DU.SI has insufficient market cap or average volume. Data not retrieved.
# F13.SI has insufficient market cap or average volume. Data not retrieved.
# 508.SI has insufficient market cap or average volume. Data not retrieved.
# BTY.SI is not an equity. Data not retrieved.
# AWK.SI has insufficient market cap or average volume. Data not retrieved.
# QS9.SI has insufficient market cap or average volume. Data not retrieved.
# G41.SI is delisted
# 5IG.SI has insufficient market cap or average volume. Data not retrieved.
# 41T.SI has insufficient market cap or average volume. Data not retrieved.
# 5VP.SI has insufficient market cap or average volume. Data not retrieved.
# XJB.SI has insufficient market cap or average volume. Data not retrieved.
# 595.SI has insufficient market cap or average volume. Data not retrieved.
# B73.SI has insufficient market cap or average volume. Data not retrieved.
# BLW.SI is delisted
# AYN.SI has insufficient market cap or average volume. Data not retrieved.
# 5PC.SI has insufficient market cap or average volume. Data not retrieved.
# G20.SI has insufficient market cap or average volume. Data not retrieved.
# G50.SI has insufficient market cap or average volume. Data not retrieved.
# JLB.SI has insufficient market cap or average volume. Data not retrieved.
# G07.SI has insufficient market cap or average volume. Data not retrieved.
# Y06.SI has insufficient market cap or average volume. Data not retrieved.
# BLU.SI has insufficient market cap or average volume. Data not retrieved.
# 43A.SI has insufficient market cap or average volume. Data not retrieved.
# BDX.SI has insufficient market cap or average volume. Data not retrieved.
# 41F.SI has insufficient market cap or average volume. Data not retrieved.
# F17.SI has insufficient market cap or average volume. Data not retrieved.
# 5AI.SI has insufficient market cap or average volume. Data not retrieved.
# 5VS.SI has insufficient market cap or average volume. Data not retrieved.
# BLH.SI has insufficient market cap or average volume. Data not retrieved.
# 5VJ.SI has insufficient market cap or average volume. Data not retrieved.
# H02.SI has insufficient market cap or average volume. Data not retrieved.
# 1B1.SI has insufficient market cap or average volume. Data not retrieved.
# 40B.SI has insufficient market cap or average volume. Data not retrieved.
# 5OR.SI has insufficient market cap or average volume. Data not retrieved.
# 5DP.SI has insufficient market cap or average volume. Data not retrieved.
# 5PD.SI has insufficient market cap or average volume. Data not retrieved.
# BTG.SI has insufficient market cap or average volume. Data not retrieved.
# 5GZ.SI has insufficient market cap or average volume. Data not retrieved.
# 5JK.SI has insufficient market cap or average volume. Data not retrieved.
# 510.SI has insufficient market cap or average volume. Data not retrieved.
# AVX.SI has insufficient market cap or average volume. Data not retrieved.
# H13.SI has insufficient market cap or average volume. Data not retrieved.
# J2T.SI has insufficient market cap or average volume. Data not retrieved.
# H20.SI has insufficient market cap or average volume. Data not retrieved.
# CTO.SI has insufficient market cap or average volume. Data not retrieved.
# H22.SI has insufficient market cap or average volume. Data not retrieved.
# S41.SI has insufficient market cap or average volume. Data not retrieved.
# BBP.SI has insufficient market cap or average volume. Data not retrieved.
# 5EV.SI has insufficient market cap or average volume. Data not retrieved.
# H18.SI has insufficient market cap or average volume. Data not retrieved.
# H12.SI has insufficient market cap or average volume. Data not retrieved.
# BLS.SI has insufficient market cap or average volume. Data not retrieved.
# P7VU.SI has insufficient market cap or average volume. Data not retrieved.
# H15.SI has insufficient market cap or average volume. Data not retrieved.
# CHZ.SI has insufficient market cap or average volume. Data not retrieved.
# 41B.SI has insufficient market cap or average volume. Data not retrieved.
# 600.SI is not an equity. Data not retrieved.
# AIY.SI has insufficient market cap or average volume. Data not retrieved.
# I49.SI has insufficient market cap or average volume. Data not retrieved.
# Q0F.SI has insufficient market cap or average volume. Data not retrieved.
# 5HT.SI has insufficient market cap or average volume. Data not retrieved.
# I4R.SI is not an equity. Data not retrieved.
# RDR.SI has insufficient market cap or average volume. Data not retrieved.
# 5JS.SI has insufficient market cap or average volume. Data not retrieved.
# M14.SI has insufficient market cap or average volume. Data not retrieved.
# I06.SI has insufficient market cap or average volume. Data not retrieved.
# AZA.SI has insufficient market cap or average volume. Data not retrieved.
# 42N.SI has insufficient market cap or average volume. Data not retrieved.
# 282 8U7U.SI
# 8U7U.SI has insufficient data. Data not retrieved.
# 40T.SI has insufficient market cap or average volume. Data not retrieved.
# I15.SI has insufficient market cap or average volume. Data not retrieved.
# NXR.SI has insufficient market cap or average volume. Data not retrieved.
# 42C.SI has insufficient market cap or average volume. Data not retrieved.
# J17.SI has insufficient market cap or average volume. Data not retrieved.
# J03.SI has insufficient market cap or average volume. Data not retrieved.
# 5OI.SI has insufficient market cap or average volume. Data not retrieved.
# C07.SI has insufficient market cap or average volume. Data not retrieved.
# 5PF.SI has insufficient market cap or average volume. Data not retrieved.
# FQ7.SI has insufficient market cap or average volume. Data not retrieved.
# 1J7.SI has insufficient market cap or average volume. Data not retrieved.
# BEW.SI has insufficient market cap or average volume. Data not retrieved.
# 1J4.SI has insufficient market cap or average volume. Data not retrieved.
# 300 EG0.SI
# EG0.SI has insufficient data. Data not retrieved.
# J36.SI has insufficient market cap or average volume. Data not retrieved.
# E9L.SI has insufficient market cap or average volume. Data not retrieved.
# 42R.SI has insufficient market cap or average volume. Data not retrieved.
# K29.SI has insufficient market cap or average volume. Data not retrieved.
# 1A0.SI has insufficient market cap or average volume. Data not retrieved.
# BNE.SI has insufficient market cap or average volume. Data not retrieved.
# 5TT.SI has insufficient market cap or average volume. Data not retrieved.
# K03.SI has insufficient market cap or average volume. Data not retrieved.
# 1D0.SI has insufficient market cap or average volume. Data not retrieved.
# 5MZ.SI has insufficient market cap or average volume. Data not retrieved.
# 5TI.SI has insufficient market cap or average volume. Data not retrieved.
# BJZ.SI has insufficient market cap or average volume. Data not retrieved.
# K75.SI has insufficient market cap or average volume. Data not retrieved.
# 5I1.SI has insufficient market cap or average volume. Data not retrieved.
# 5VC.SI has insufficient market cap or average volume. Data not retrieved.
# 5OC.SI has insufficient market cap or average volume. Data not retrieved.
# SK3.SI is not an equity. Data not retrieved.
# 578.SI has insufficient market cap or average volume. Data not retrieved.
# ER0.SI has insufficient market cap or average volume. Data not retrieved.
# EB7.SI has insufficient market cap or average volume. Data not retrieved.
# XCF.SI has insufficient market cap or average volume. Data not retrieved.
# GIH.SI has insufficient market cap or average volume. Data not retrieved.
# BEI.SI has insufficient market cap or average volume. Data not retrieved.
# 1D3.SI has insufficient market cap or average volume. Data not retrieved.
# BFT.SI has insufficient market cap or average volume. Data not retrieved.
# BAZ.SI has insufficient market cap or average volume. Data not retrieved.
# PRH.SI has insufficient market cap or average volume. Data not retrieved.
# LMS.SI has insufficient market cap or average volume. Data not retrieved.
# O6Z.SI is not an equity. Data not retrieved.
# 5IE.SI has insufficient market cap or average volume. Data not retrieved.
# F1E.SI has insufficient market cap or average volume. Data not retrieved.
# ENV.SI has insufficient market cap or average volume. Data not retrieved.
# L19.SI has insufficient market cap or average volume. Data not retrieved.
# 5UA.SI has insufficient market cap or average volume. Data not retrieved.
# L09.SI has insufficient market cap or average volume. Data not retrieved.
# BKK.SI has insufficient market cap or average volume. Data not retrieved.
# 1H8.SI has insufficient market cap or average volume. Data not retrieved.
# 41S.SI is not an equity. Data not retrieved.
# M04.SI has insufficient market cap or average volume. Data not retrieved.
# M12.SI is not an equity. Data not retrieved.
# 5OX.SI has insufficient market cap or average volume. Data not retrieved.
# Y3D.SI has insufficient market cap or average volume. Data not retrieved.
# Z4D.SI has insufficient market cap or average volume. Data not retrieved.
# OTX.SI has insufficient market cap or average volume. Data not retrieved.
# 5DS.SI has insufficient market cap or average volume. Data not retrieved.
# SJY.SI has insufficient market cap or average volume. Data not retrieved.
# TWL.SI has insufficient market cap or average volume. Data not retrieved.
# 5RF.SI has insufficient market cap or average volume. Data not retrieved.
# 5DX.SI has insufficient market cap or average volume. Data not retrieved.
# V3M.SI has insufficient market cap or average volume. Data not retrieved.
# L02.SI has insufficient market cap or average volume. Data not retrieved.
# M01.SI has insufficient market cap or average volume. Data not retrieved.
# MV4.SI has insufficient market cap or average volume. Data not retrieved.
# M11.SI has insufficient market cap or average volume. Data not retrieved.
# 5DD.SI has insufficient market cap or average volume. Data not retrieved.
# 5EN.SI has insufficient market cap or average volume. Data not retrieved.
# CNE.SI has insufficient market cap or average volume. Data not retrieved.
# M03.SI has insufficient market cap or average volume. Data not retrieved.
# 5WJ.SI has insufficient market cap or average volume. Data not retrieved.
# 1V3.SI has insufficient market cap or average volume. Data not retrieved.
# NPW.SI has insufficient market cap or average volume. Data not retrieved.
# 5QR.SI has insufficient market cap or average volume. Data not retrieved.
# M05.SI has insufficient market cap or average volume. Data not retrieved.
# AWZ.SI has insufficient market cap or average volume. Data not retrieved.
# MF6.SI has insufficient market cap or average volume. Data not retrieved.
# PJX.SI is not an equity. Data not retrieved.
# F86.SI has insufficient market cap or average volume. Data not retrieved.
# N4E.SI has insufficient market cap or average volume. Data not retrieved.
# G0I.SI has insufficient market cap or average volume. Data not retrieved.
# 5IF.SI has insufficient market cap or average volume. Data not retrieved.
# 42D.SI has insufficient market cap or average volume. Data not retrieved.
# N01.SI has insufficient market cap or average volume. Data not retrieved.
# BMT.SI has insufficient market cap or average volume. Data not retrieved.
# N08.SI has insufficient market cap or average volume. Data not retrieved.
# 5FX.SI has insufficient market cap or average volume. Data not retrieved.
# 5GF.SI is delisted
# NIO.SI has insufficient market cap or average volume. Data not retrieved.
# 1G6.SI has insufficient market cap or average volume. Data not retrieved.
# 543.SI has insufficient market cap or average volume. Data not retrieved.
# N33.SI is not an equity. Data not retrieved.
# SEJ.SI has insufficient market cap or average volume. Data not retrieved.
# MR7.SI has insufficient market cap or average volume. Data not retrieved.
# NTA.SI has insufficient market cap or average volume. Data not retrieved.
# N02.SI has insufficient market cap or average volume. Data not retrieved.
# WVJ.SI has insufficient market cap or average volume. Data not retrieved.
# AZT.SI has insufficient market cap or average volume. Data not retrieved.
# 1B6.SI has insufficient market cap or average volume. Data not retrieved.
# 584.SI has insufficient market cap or average volume. Data not retrieved.
# HQU.SI has insufficient market cap or average volume. Data not retrieved.
# KUX.SI has insufficient market cap or average volume. Data not retrieved.
# S3N.SI has insufficient market cap or average volume. Data not retrieved.
# 5CF.SI has insufficient market cap or average volume. Data not retrieved.
# 5ML.SI has insufficient market cap or average volume. Data not retrieved.
# 1H2.SI has insufficient market cap or average volume. Data not retrieved.
# 5SY.SI has insufficient market cap or average volume. Data not retrieved.
# O08.SI has insufficient market cap or average volume. Data not retrieved.
# OTS.SI has insufficient market cap or average volume. Data not retrieved.
# LJ3.SI has insufficient market cap or average volume. Data not retrieved.
# AJ2.SI has insufficient market cap or average volume. Data not retrieved.
# RQ1.SI has insufficient market cap or average volume. Data not retrieved.
# TVV.SI has insufficient market cap or average volume. Data not retrieved.
# P11.SI is not an equity. Data not retrieved.
# P15.SI has insufficient market cap or average volume. Data not retrieved.
# 1C5.SI is delisted
# P36.SI has insufficient market cap or average volume. Data not retrieved.
# P52.SI has insufficient market cap or average volume. Data not retrieved.
# C2PU.SI has insufficient market cap or average volume. Data not retrieved.
# 596.SI has insufficient market cap or average volume. Data not retrieved.
# IX2.SI has insufficient market cap or average volume. Data not retrieved.
# PGS.SI has insufficient market cap or average volume. Data not retrieved.
# BTM.SI has insufficient market cap or average volume. Data not retrieved.
# BFK.SI has insufficient market cap or average volume. Data not retrieved.
# YYN.SI has insufficient market cap or average volume. Data not retrieved.
# BDA.SI has insufficient market cap or average volume. Data not retrieved.
# 5BI.SI has insufficient market cap or average volume. Data not retrieved.
# BCY.SI has insufficient market cap or average volume. Data not retrieved.
# BVQ.SI has insufficient market cap or average volume. Data not retrieved.
# 583.SI has insufficient market cap or average volume. Data not retrieved.
# K6S.SI has insufficient market cap or average volume. Data not retrieved.
# DM0.SI has insufficient market cap or average volume. Data not retrieved.
# QC7.SI has insufficient market cap or average volume. Data not retrieved.
# Q01.SI has insufficient market cap or average volume. Data not retrieved.
# BCV.SI has insufficient market cap or average volume. Data not retrieved.
# LUY.SI has insufficient market cap or average volume. Data not retrieved.
# 1G1.SI has insufficient market cap or average volume. Data not retrieved.
# NEX.SI has insufficient market cap or average volume. Data not retrieved.
# 5EC.SI has insufficient market cap or average volume. Data not retrieved.
# UV1.SI has insufficient market cap or average volume. Data not retrieved.
# I11.SI has insufficient market cap or average volume. Data not retrieved.
# QSD.SI has insufficient market cap or average volume. Data not retrieved.
# RCU.SI has insufficient market cap or average volume. Data not retrieved.
# RF1U.SI is not an equity. Data not retrieved.
# 5G4.SI has insufficient market cap or average volume. Data not retrieved.
# 5DO.SI has insufficient market cap or average volume. Data not retrieved.
# E6R.SI has insufficient market cap or average volume. Data not retrieved.
# Y8E.SI has insufficient market cap or average volume. Data not retrieved.
# 1000.SI is delisted
# 580.SI has insufficient market cap or average volume. Data not retrieved.
# BRD.SI has insufficient market cap or average volume. Data not retrieved.
# U77.SI has insufficient market cap or average volume. Data not retrieved.
# 5PL.SI has insufficient market cap or average volume. Data not retrieved.
# S61.SI has insufficient market cap or average volume. Data not retrieved.
# 528.SI has insufficient market cap or average volume. Data not retrieved.
# 43B.SI has insufficient market cap or average volume. Data not retrieved.
# 5BS.SI has insufficient market cap or average volume. Data not retrieved.
# S69.SI has insufficient market cap or average volume. Data not retrieved.
# IW5.SI has insufficient market cap or average volume. Data not retrieved.
# 5EW.SI has insufficient market cap or average volume. Data not retrieved.
# SES.SI has insufficient market cap or average volume. Data not retrieved.
# AWM.SI has insufficient market cap or average volume. Data not retrieved.
# S07.SI has insufficient market cap or average volume. Data not retrieved.
# A78.SI has insufficient market cap or average volume. Data not retrieved.
# BKV.SI has insufficient market cap or average volume. Data not retrieved.
# 1F0.SI has insufficient market cap or average volume. Data not retrieved.
# 566.SI has insufficient market cap or average volume. Data not retrieved.
# S59.SI has insufficient market cap or average volume. Data not retrieved.
# BHK.SI has insufficient market cap or average volume. Data not retrieved.
# 5CP.SI has insufficient market cap or average volume. Data not retrieved.
# URR.SI has insufficient market cap or average volume. Data not retrieved.
# BKA.SI has insufficient market cap or average volume. Data not retrieved.
# A26.SI has insufficient market cap or average volume. Data not retrieved.
# 5UN.SI has insufficient market cap or average volume. Data not retrieved.
# S35.SI has insufficient market cap or average volume. Data not retrieved.
# FRQ.SI has insufficient market cap or average volume. Data not retrieved.
# 5WG.SI has insufficient market cap or average volume. Data not retrieved.
# U06.SI has insufficient market cap or average volume. Data not retrieved.
# 5IC.SI has insufficient market cap or average volume. Data not retrieved.
# S19.SI has insufficient market cap or average volume. Data not retrieved.
# Z77.SI has insufficient market cap or average volume. Data not retrieved.
# 5HH.SI has insufficient market cap or average volume. Data not retrieved.
# T4B.SI has insufficient market cap or average volume. Data not retrieved.
# LYY.SI has insufficient market cap or average volume. Data not retrieved.
# C9Q.SI has insufficient market cap or average volume. Data not retrieved.
# 5LE.SI has insufficient market cap or average volume. Data not retrieved.
# 1J0.SI has insufficient market cap or average volume. Data not retrieved.
# S7P.SI has insufficient market cap or average volume. Data not retrieved.
# 5MD.SI has insufficient market cap or average volume. Data not retrieved.
# 5KI.SI has insufficient market cap or average volume. Data not retrieved.
# A33.SI has insufficient market cap or average volume. Data not retrieved.
# BQP.SI has insufficient market cap or average volume. Data not retrieved.
# QNS.SI has insufficient market cap or average volume. Data not retrieved.
# 40E.SI has insufficient market cap or average volume. Data not retrieved.
# 564.SI has insufficient market cap or average volume. Data not retrieved.
# S23.SI has insufficient market cap or average volume. Data not retrieved.
# NC2.SI has insufficient market cap or average volume. Data not retrieved.
# STG.SI has insufficient market cap or average volume. Data not retrieved.
# DRX.SI has insufficient market cap or average volume. Data not retrieved.
# H07.SI has insufficient market cap or average volume. Data not retrieved.
# S29.SI has insufficient market cap or average volume. Data not retrieved.
# S85.SI has insufficient market cap or average volume. Data not retrieved.
# S20.SI has insufficient market cap or average volume. Data not retrieved.
# 5GD.SI has insufficient market cap or average volume. Data not retrieved.
# S71.SI has insufficient market cap or average volume. Data not retrieved.
# 581.SI has insufficient market cap or average volume. Data not retrieved.
# BKZ.SI has insufficient market cap or average volume. Data not retrieved.
# BHU.SI has insufficient market cap or average volume. Data not retrieved.
# BGK.SI is not an equity. Data not retrieved.
# BEV.SI is not an equity. Data not retrieved.
# 5UO.SI has insufficient market cap or average volume. Data not retrieved.
# PA3.SI has insufficient market cap or average volume. Data not retrieved.
# 500.SI has insufficient market cap or average volume. Data not retrieved.
# 42L.SI has insufficient market cap or average volume. Data not retrieved.
# 5G3.SI has insufficient market cap or average volume. Data not retrieved.
# T12.SI has insufficient market cap or average volume. Data not retrieved.
# VI2.SI has insufficient market cap or average volume. Data not retrieved.
# T15.SI has insufficient market cap or average volume. Data not retrieved.
# M1Z.SI has insufficient market cap or average volume. Data not retrieved.
# 5OQ.SI has insufficient market cap or average volume. Data not retrieved.
# T41.SI has insufficient market cap or average volume. Data not retrieved.
# AWI.SI has insufficient market cap or average volume. Data not retrieved.
# AGS.SI has insufficient market cap or average volume. Data not retrieved.
# T55.SI has insufficient market cap or average volume. Data not retrieved.
# BFI.SI has insufficient market cap or average volume. Data not retrieved.
# BQM.SI has insufficient market cap or average volume. Data not retrieved.
# T14.SI has insufficient market cap or average volume. Data not retrieved.
# S2D.SI is not an equity. Data not retrieved.
# BCZ.SI has insufficient market cap or average volume. Data not retrieved.
# 5AB.SI has insufficient market cap or average volume. Data not retrieved.
# 42T.SI has insufficient market cap or average volume. Data not retrieved.
# CYW.SI has insufficient market cap or average volume. Data not retrieved.
# RC5.SI is not an equity. Data not retrieved.
# KUH.SI has insufficient market cap or average volume. Data not retrieved.
# T09.SI is not an equity. Data not retrieved.
# T24.SI has insufficient market cap or average volume. Data not retrieved.
# 540.SI has insufficient market cap or average volume. Data not retrieved.
# BFU.SI has insufficient market cap or average volume. Data not retrieved.
# 8K7.SI has insufficient market cap or average volume. Data not retrieved.
# CHJ.SI has insufficient market cap or average volume. Data not retrieved.
# 1F2.SI has insufficient market cap or average volume. Data not retrieved.
# BLA.SI has insufficient market cap or average volume. Data not retrieved.
# AZR.SI has insufficient market cap or average volume. Data not retrieved.
# BGO.SI is not an equity. Data not retrieved.
# 1D1.SI has insufficient market cap or average volume. Data not retrieved.
# EH5.SI has insufficient market cap or average volume. Data not retrieved.
# U10.SI has insufficient market cap or average volume. Data not retrieved.
# U13.SI has insufficient market cap or average volume. Data not retrieved.
# BRS.SI has insufficient market cap or average volume. Data not retrieved.
# ODBU.SI has insufficient market cap or average volume. Data not retrieved.
# V2Y.SI has insufficient market cap or average volume. Data not retrieved.
# WPC.SI has insufficient market cap or average volume. Data not retrieved.
# T6I.SI has insufficient market cap or average volume. Data not retrieved.
# BN2.SI has insufficient market cap or average volume. Data not retrieved.
# 40N.SI has insufficient market cap or average volume. Data not retrieved.
# VT1.SI has insufficient market cap or average volume. Data not retrieved.
# BIP.SI has insufficient market cap or average volume. Data not retrieved.
# BJD.SI has insufficient market cap or average volume. Data not retrieved.
# WJP.SI has insufficient market cap or average volume. Data not retrieved.
# 569.SI has insufficient market cap or average volume. Data not retrieved.
# E3B.SI has insufficient market cap or average volume. Data not retrieved.
# BDR.SI has insufficient market cap or average volume. Data not retrieved.
# W05.SI has insufficient market cap or average volume. Data not retrieved.
# 1A1.SI has insufficient market cap or average volume. Data not retrieved.
# B49.SI has insufficient market cap or average volume. Data not retrieved.
# BQF.SI has insufficient market cap or average volume. Data not retrieved.
# 1F1.SI has insufficient market cap or average volume. Data not retrieved.
# BJV.SI has insufficient market cap or average volume. Data not retrieved.
# Y03.SI has insufficient market cap or average volume. Data not retrieved.
# BPF.SI has insufficient market cap or average volume. Data not retrieved.
# 5DM.SI has insufficient market cap or average volume. Data not retrieved.
# YK9.SI has insufficient market cap or average volume. Data not retrieved.
# BKX.SI has insufficient market cap or average volume. Data not retrieved.
# AXB.SI has insufficient market cap or average volume. Data not retrieved.
# T43.SI has insufficient market cap or average volume. Data not retrieved.
# AFC.SI is not an equity. Data not retrieved.
# 647 SO7.SI
# SO7.SI has insufficient data. Data not retrieved.
# BWM.SI has insufficient market cap or average volume. Data not retrieved.
# 5SR.SI has insufficient market cap or average volume. Data not retrieved.
# 5EG.SI has insufficient market cap or average volume. Data not retrieved.
# 40W.SI has insufficient market cap or average volume. Data not retrieved.
# 151 tickers have sufficient market cap and average volume.

# %%
copy = ticker_source.copy()
print(f'{len(delisted)} delisted stocks')
print(f'{len(non_equity)} non-equity stocks')
print(f'{len(insufficient_data)} stocks with insufficient data')
print(f'{len(insufficient_market_cap)} stocks with insufficient market cap, volume or trade date after 2010-01-01')
to_drop = delisted + non_equity + insufficient_data + insufficient_market_cap
ticker_source.drop(to_drop, inplace=True)
print(f'{len(ticker_source)} stocks remaining')
# Out:
# 151 stocks remaining

# %%
ticker_source.head()
# Out:
#    S.No.  Trading Name    Code                            Sector
# 0      1       3Cnergy  502.SI                       Real Estate
# 1      2  5E Resources  NLC.SI  Industrial & Commercial Services
# 2      3      8Telecom  AZG.SI              Technology Equipment
# 3      4            9R  1Y1.SI                  Industrial Goods
# 4      5           ABR  533.SI                  Food & Beverages

# %%
connection = sqlite3.connect('database.db')
cursor = connection.cursor()
cursor.execute('CREATE TABLE IF NOT EXISTS equities (id INTEGER PRIMARY KEY, name TEXT, ticker TEXT, sector TEXT)')
data = cursor.execute('SELECT * FROM equities').fetchall()

if data == []:
    for idx,stock in enumerate(ticker_source.iterrows()):
        cursor.execute(f'INSERT INTO equities VALUES ({idx}, "{stock[1][1]}", "{stock[1][2]}", "{stock[1][3]}")')
else:
    data = pd.DataFrame(data, columns=['id', 'name', 'ticker', 'sector'])
    print(data)
connection.commit()
connection.close()
# Out:
#       id              name  ticker                            sector
# 0      0           3Cnergy  502.SI                       Real Estate
# 1      1      5E Resources  NLC.SI  Industrial & Commercial Services
# 2      2          8Telecom  AZG.SI              Technology Equipment
# 3      3                9R  1Y1.SI                  Industrial Goods
# 4      4               ABR  533.SI                  Food & Beverages
# ..   ...               ...     ...                               ...
# 649  649  Zheneng Jinjiang  BWM.SI                  Renewable Energy
# 650  650   Zhongmin Baihui  5SR.SI                         Retailers
# 651  651    Zhongxin Fruit  5EG.SI                  Food & Beverages
# 652  652        ZICO Hldgs  40W.SI     Banking & Investment Services
# 653  653             Zixin  42W.SI                  Food & Beverages
#
# [654 rows x 4 columns]
